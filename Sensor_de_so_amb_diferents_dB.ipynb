# %% [markdown]
# <a href="https://colab.research.google.com/github/rlopezortega/Programacion/blob/main/Sensor_de_so_amb_diferents_dB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !python --version
# !apt-get install python3.12



import pandas as pd

df=pd.read_csv("/content/Micro_bit 3 - Full 1.csv")
df
# Out:
# ...
# Python 3.11.11
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   libpython3.12-stdlib
# Suggested packages:
#   python3.12-venv
# The following NEW packages will be installed:
#   libpython3.12-stdlib python3.12
# 0 upgraded, 2 newly installed, 0 to remove and 20 not upgraded.
# Need to get 5,418 kB of archives.
# After this operation, 22.6 MB of additional disk space will be used.
# Get:1 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 libpython3.12-stdlib amd64 3.12.9-1+jammy1 [2,892 kB]
# Get:2 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy/main amd64 python3.12 amd64 3.12.9-1+jammy1 [2,526 kB]
# Fetched 5,418 kB in 2s (2,354 kB/s)
# Selecting previously unselected package libpython3.12-stdlib:amd64.
# (Reading database ... 124926 files and directories currently installed.)
# ...

# %%
from matplotlib import pyplot as plt
df['Música passadís'].plot(kind='line', figsize=(8, 4), title='Música passadís')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['Música a23'].plot(kind='line', figsize=(8, 4), title='Música a23')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['Música a14'].plot(kind='line', figsize=(8, 4), title='Música a14')
plt.gca().spines[['top', 'right']].set_visible(False)
