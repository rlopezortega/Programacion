# %% [markdown]
# <a href="https://colab.research.google.com/github/rlopezortega/Programacion/blob/main/csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
x= pd.read_csv("csv - Full 1 (1).csv")
x
# Out:
#     International Designator National Designator Name of Space Object  \
# 0                  2019-097A                 NaN                SJ 20
# 1                [2019-096C]       3538-2019-021       Gonets M No.26
# 2                [2019-096B]       3537-2019-021       Gonets M No.25
# 3                [2019-096A]       3536-2019-021       Gonets M No.24
# 4                [2019-096E]                 NaN     [BLITS M/DM R/B]
# ..                       ...                 ...                  ...
# 582                2019-002B                 NaN          Iridium 176
# 583                2019-002G                 NaN          Iridium 175
# 584                2019-002A                 NaN          Iridium 180
# 585                2019-001A                 NaN          Chinasat 2D
# 586                      NaN                 NaN                  NaN
#
#                     State Date of Launch         GSO Location  \
# 0                   China     2019-12-27                  NaN
# ...

# %% [markdown]
# ·Calculeu quants objectes en òrbita són de: «Russian Federation», «China», «USA» i «ESA»
#
# ·Què és la ESA? Responeu-ho al mig del codi, amb una anotació.
#
# ·Calculeu quants satèl·lits estan en òrbita i quants ja no ho estan.
#
# ·Quan va deixar de ser funcional aquest satèl·lit? (2019-092F) → status = #decayed

# %%
x1 = x["State"].str.contains("Russian Federation") #Puc fer els true o false en cada cas
x1.value_counts() #suma els true o false i els separa en dues filesamb el resultat
x1[x1==True].count().sum() #fa el sumatori dels true
# Out:
# 30

# %%
x1 = x["State"].str.contains("China") #Puc fer els true o false en cada cas
x1.value_counts() #suma els true o false i els separa en dues filesamb el resultat
x1[x1==True].count().sum() #fa el sumatori dels true
# Out:
# 82

# %%
x1 = x["State"].str.contains("USA") #Puc fer els true o false en cada cas
x1.value_counts() #suma els true o false i els separa en dues filesamb el resultat
x1[x1==True].count().sum() #fa el sumatori dels true
# Out:
# 362

# %%
x1 = x["State"].str.contains("ESA") #Puc fer els true o false en cada cas
x1.value_counts() #suma els true o false i els separa en dues filesamb el resultat
x1[x1==True].count().sum() #fa el sumatori dels true
# Out:
# 2

# %%
x1 = x["Status"].str.contains("in orbit") #Puc fer els true o false en cada cas
x1.value_counts() #suma els true o false i els separa en dues filesamb el resultat
x1[x1==True].count().sum() #fa el sumatori dels true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-288d9b4c9e3a> in <cell line: 1>()
# ----> 1 x1 = x["Status"].str.contains("in orbit") #Puc fer els true o false en cada cas
#       2 x1.value_counts() #suma els true o false i els separa en dues filesamb el resultat
#       3 x1[x1==True].count().sum() #fa el sumatori dels true
#
# NameError: name 'x' is not defined

# %%
x1 = x["Status"].str.contains("decayed")#Puc fer els true o false en cada cas
x1.value_counts() #suma els true o false i els separa en dues filesamb el resultat
x1[x1==True].count().sum() #fa el sumatori dels true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-536284fd74b2> in <cell line: 1>()
# ----> 1 x1 = x["Status"].str.contains("decayed")#Puc fer els true o false en cada cas
#       2 x1.value_counts() #suma els true o false i els separa en dues filesamb el resultat
#       3 x1[x1==True].count().sum() #fa el sumatori dels true
#
# NameError: name 'x' is not defined

# %%
x2 = .loc[xnoosa['International Designator'].str.contains('2019-092F')] #localitzar linia del satèl·lit
x2["Date of Decay or Change"] #mostrar columna del decay
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3e8f5216654f> in <cell line: 1>()
# ----> 1 x2 = noosa.loc[noosa['International Designator'].str.contains('2019-092F')] #localitzar linia del satèl·lit
#       2 x2["Date of Decay or Change"] #mostrar columna del decay
#
# NameError: name 'noosa' is not defined
