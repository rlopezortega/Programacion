# %% [markdown]
# <a href="https://colab.research.google.com/github/rlopezortega/Programacion/blob/main/Sensor_llum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !python --version
# !apt-get install python3.12



import pandas as pd

df=pd.read_csv("/microbit - Full 1 (1).csv")
df
# Out:
# ...
# Python 3.10.12
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.12 is already the newest version (3.12.8-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
#      Aula 14  Lluminositat aula14    Pati  Lluminositat pati   Pasadís  \
# 0        NaN                  NaN     NaN                NaN       NaN
# 1        NaN                  NaN     NaN                NaN       NaN
# 2       0.00                 89.0     0.0              254.0       0.0
# 3       2.86                 96.0  3772.0              254.0     876.0
# 4       5.72                 52.0  7544.0              254.0    1752.0
# ..       ...                  ...     ...                ...       ...
# 144      NaN                  NaN     NaN                NaN  124393.0
# 145      NaN                  NaN     NaN                NaN  125269.0
# 146      NaN                  NaN     NaN                NaN  126145.0
# ...

# %%
from matplotlib import pyplot as plt
df['Lluminositat aula14'].plot(kind='line', figsize=(8, 4), title='Lluminositat aula14')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['Lluminositat pati'].plot(kind='line', figsize=(8, 4), title='Lluminositat pati')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df['Lluminositat pasadís'].plot(kind='line', figsize=(8, 4), title='Lluminositat pasadís')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
max_u = df['Aula 14'].max()
print(max_u)
min_u = df['Aula 14'].min()
print(min_u)




max_dos = df['Pati'].max()
print(max_dos)
min_dos = df['Pati'].min()
print(min_dos)




max_tres = df['Pasadís'].max()
print(max_tres)
min_tres = df['Pasadís'].min()
print(min_tres)
# Out:
# 190213.0
# 0.0
# 181052.0
# 0.0
# 127898.0
# 0.0
