# %% [markdown]
# <a href="https://colab.research.google.com/github/rlopezortega/Programacion/blob/main/Temperatura_i_humitat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
# !python --version
# !apt-get install python3.12



import pandas as pd

df=pd.read_csv("/Temperatura i humitat - Full 1.csv")
df
# Out:
# ...
# Python 3.11.11
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.12 is already the newest version (3.12.9-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
#     Temperatura a14  Humitat a14  Temperatura gimnàs  Humitat gimnàs  \
# 0              23.0         51.0                20.0            61.0
# 1              23.0         51.0                20.0            61.0
# 2              23.0         51.0                20.0            61.0
# 3              23.0         51.0                20.0            61.0
# 4              23.0         51.0                20.0            61.0
# ..              ...          ...                 ...             ...
# 95             23.0         51.0                20.0            63.0
# 96             23.0         51.0                20.0            63.0
# 97             23.0         51.0                20.0            63.0
# ...

# %%
max = df.max()
print(max)
# Out:
# Temperatura a14                23.0
# Humitat a14                    51.0
# Temperatura gimnàs             20.0
# Humitat gimnàs                 63.0
# Temperatura pati               17.0
# Humitat pati                   64.0
# Temperatura sala professors    22.0
# Humitat sala professors        38.0
# Temperatura lavabo noies       20.0
# Humitat lavabo noies           37.0
# dtype: float64

# %%
min = df.min()
print(min)
# Out:
# Temperatura a14                23.0
# Humitat a14                    51.0
# Temperatura gimnàs             20.0
# Humitat gimnàs                 61.0
# Temperatura pati               17.0
# Humitat pati                   64.0
# Temperatura sala professors    22.0
# Humitat sala professors        38.0
# Temperatura lavabo noies       20.0
# Humitat lavabo noies           37.0
# dtype: float64

# %%
media=df.mean()
print(round(media,2))
# Out:
# Temperatura a14                23.00
# Humitat a14                    51.00
# Temperatura gimnàs             20.00
# Humitat gimnàs                 62.42
# Temperatura pati               17.00
# Humitat pati                   64.00
# Temperatura sala professors    22.00
# Humitat sala professors        38.00
# Temperatura lavabo noies       20.00
# Humitat lavabo noies           37.00
# dtype: float64
